# %%
import pandas as pd

# %%
trisolaris_results = {'machine_info': {'system': {'system': 'Linux', 'node': 'trisolaris', 'release': '5.19.0-32-generic'}, 'cpu': {'model': 'AMD Ryzen 7 2700 Eight-Core Processor', 'architecture': 'x86_64', 'cores': {'physical': 8, 'total': 16}, 'frequency': '3.20 GHz'}, 'memory': {'total': '31.28 GB', 'used': '12.81 GB', 'available': '17.60 GB'}, 'gpus': [{'name': 'NVIDIA GeForce RTX 3060', 'memory': '12288.0 MB'}]}, 'device': 'cpu', 'params': 5288548, 'flops': 401669732, 'timing': {'batch_size_1': {'on_device_inference': {'metrics': {'batches_per_second_mean': 45.217218399054765, 'batches_per_second_std': 2.547259593904245, 'batches_per_second_min': 32.137305381880594, 'batches_per_second_max': 49.290243730462784, 'seconds_per_batch_mean': 0.022191896915435792, 'seconds_per_batch_std': 0.0013653915227031985, 'seconds_per_batch_min': 0.02028799057006836, 'seconds_per_batch_max': 0.031116485595703125}, 'human_readable': {'batches_per_second': '45.22 +/- 2.55 [32.14, 49.29]', 'batch_latency': '22.192 ms +/- 1.365 ms [20.288 ms, 31.116 ms]'}}}, 'batch_size_8': {'on_device_inference': {'metrics': {'batches_per_second_mean': 6.394880599638025, 'batches_per_second_std': 0.40816574861835064, 'batches_per_second_min': 4.71355380018183, 'batches_per_second_max': 7.239259695227509, 'seconds_per_batch_mean': 0.15707258534431456, 'seconds_per_batch_std': 0.010989477161104422, 'seconds_per_batch_min': 0.13813567161560059, 'seconds_per_batch_max': 0.21215415000915527}, 'human_readable': {'batches_per_second': '6.39 +/- 0.41 [4.71, 7.24]', 'batch_latency': '157.073 ms +/- 10.989 ms [138.136 ms, 212.154 ms]'}}}}}

marvin_results = {'machine_info': {'system': {'system': 'Linux', 'node': 'marvin', 'release': '5.15.0-67-generic'}, 'cpu': {'model': '13th Gen Intel(R) Core(TM) i7-13700K', 'architecture': 'x86_64', 'cores': {'physical': 16, 'total': 24}, 'frequency': '5.10 GHz'}, 'memory': {'total': '62.60 GB', 'used': '873.14 MB', 'available': '61.04 GB'}, 'gpus': [{'name': 'NVIDIA GeForce RTX 4090', 'memory': '24564.0 MB'}]}, 'device': 'cpu', 'params': 5288548, 'flops': 401669732, 'timing': {'batch_size_1': {'on_device_inference': {'metrics': {'batches_per_second_mean': 109.18959602359185, 'batches_per_second_std': 19.13968703833374, 'batches_per_second_min': 31.888572949137078, 'batches_per_second_max': 131.67689071673, 'seconds_per_batch_mean': 0.0094909987449646, 'seconds_per_batch_std': 0.001978192790610319, 'seconds_per_batch_min': 0.00759434700012207, 'seconds_per_batch_max': 0.031359195709228516}, 'human_readable': {'batches_per_second': '109.19 +/- 19.14 [31.89, 131.68]', 'batch_latency': '9.491 ms +/- 1.978 ms [7.594 ms, 31.359 ms]'}}}, 'batch_size_8': {'on_device_inference': {'metrics': {'batches_per_second_mean': 18.29216317429411, 'batches_per_second_std': 0.08211457652612132, 'batches_per_second_min': 18.187472627539407, 'batches_per_second_max': 19.152510331286102, 'seconds_per_batch_mean': 0.05466928648948669, 'seconds_per_batch_std': 0.00023762009575384045, 'seconds_per_batch_min': 0.05221247673034668, 'seconds_per_batch_max': 0.054982900619506836}, 'human_readable': {'batches_per_second': '18.29 +/- 0.08 [18.19, 19.15]', 'batch_latency': '54.669 ms +/- 237.620 us [52.212 ms, 54.983 ms]'}}}}}

# %%
trisolaris = pd.DataFrame(trisolaris_results)
marvin = pd.DataFrame(marvin_results)

# %%
trisolaris
# Out:
#                                                    machine_info device  \
# system        {'system': 'Linux', 'node': 'trisolaris', 'rel...    cpu
# cpu           {'model': 'AMD Ryzen 7 2700 Eight-Core Process...    cpu
# memory        {'total': '31.28 GB', 'used': '12.81 GB', 'ava...    cpu
# gpus          [{'name': 'NVIDIA GeForce RTX 3060', 'memory':...    cpu
# batch_size_1                                                NaN    cpu
# batch_size_8                                                NaN    cpu
#
#                params      flops  \
# system        5288548  401669732
# cpu           5288548  401669732
# memory        5288548  401669732
# gpus          5288548  401669732
# batch_size_1  5288548  401669732
# batch_size_8  5288548  401669732
#
#                                                          timing
# system                                                      NaN
# cpu                                                         NaN
# ...

# %%
metrics = ["batches_per_second_mean", "batches_per_second_max", "batches_per_second_min"]
metric_color = ["blue", "red", "red"]
metric_marker = ["o", "x", "x"]
trisolaris.timing.batch_size_8["on_device_inference"]["metrics"]#[metrics]
# Out:
# {'batches_per_second_mean': 6.394880599638025,
#  'batches_per_second_std': 0.40816574861835064,
#  'batches_per_second_min': 4.71355380018183,
#  'batches_per_second_max': 7.239259695227509,
#  'seconds_per_batch_mean': 0.15707258534431456,
#  'seconds_per_batch_std': 0.010989477161104422,
#  'seconds_per_batch_min': 0.13813567161560059,
#  'seconds_per_batch_max': 0.21215415000915527}

# %%
import matplotlib.pyplot as plt

bars = ('min', 'min', 'mean', 'mean', 'max', 'max')
x_pos = range(len(bars))

plt.bar(0, trisolaris.timing.batch_size_8["on_device_inference"]["metrics"]["batches_per_second_min"],  color="orange", alpha=0.5, label="AMD Ryzen 2700 w/ 32GB RAM")#, marker=metric_marker[i])
plt.bar(2, trisolaris.timing.batch_size_8["on_device_inference"]["metrics"]["batches_per_second_mean"],  color="orange", alpha=0.5)#, marker=metric_marker[i])
plt.bar(4, trisolaris.timing.batch_size_8["on_device_inference"]["metrics"]["batches_per_second_max"], color="orange", alpha=0.5)#, marker=metric_marker[i])

plt.bar(1, marvin.timing.batch_size_8["on_device_inference"]["metrics"]["batches_per_second_min"], color="blue", alpha=0.5, label="Intel i7 13700K w/ 64GB RAM")#, marker=metric_marker[i])
plt.bar(3, marvin.timing.batch_size_8["on_device_inference"]["metrics"]["batches_per_second_mean"],color="blue", alpha=0.5)#, marker=metric_marker[i])
plt.bar(5, marvin.timing.batch_size_8["on_device_inference"]["metrics"]["batches_per_second_max"], color="blue", alpha=0.5)#, marker=metric_marker[i])

# Choose the names of the bars

# Create bars

# Create names on the x-axis
plt.xticks(x_pos, bars, color='black')
plt.yticks(color='black')
plt.ylabel("Batches per second")

plt.title("Simple CPU Benchmark Comparison -- Higher is Better \n Batch Size = 8, N Samples = 1000")
plt.legend(loc="lower right")

# %%
marvin_results_gpu = {'machine_info': {'system': {'system': 'Linux', 'node': 'marvin', 'release': '5.15.0-67-generic'}, 'cpu': {'model': '13th Gen Intel(R) Core(TM) i7-13700K', 'architecture': 'x86_64', 'cores': {'physical': 16, 'total': 24}, 'frequency': '5.10 GHz'}, 'memory': {'total': '62.60 GB', 'used': '1.56 GB', 'available': '60.33 GB'}, 'gpus': [{'name': 'NVIDIA GeForce RTX 4090', 'memory': '24564.0 MB'}]}, 'device': 'cuda', 'params': 5288548, 'timing': {'batch_size_1': {'on_device_inference': {'metrics': {'batches_per_second_mean': 321.64704620513555, 'batches_per_second_std': 1.9738454184828442, 'batches_per_second_min': 312.0065461578517, 'batches_per_second_max': 326.5828856186249, 'seconds_per_batch_mean': 0.0031091156005859373, 'seconds_per_batch_std': 1.9176432169551848e-05, 'seconds_per_batch_min': 0.003062009811401367, 'seconds_per_batch_max': 0.0032050609588623047}, 'human_readable': {'batches_per_second': '321.65 +/- 1.97 [312.01, 326.58]', 'batch_latency': '3.109 ms +/- 19.176 us [3.062 ms, 3.205 ms]'}}, 'cpu_to_gpu': {'metrics': {'batches_per_second_mean': 21143.602872090738, 'batches_per_second_std': 502.59662058493285, 'batches_per_second_min': 18477.110132158592, 'batches_per_second_max': 21620.123711340206, 'seconds_per_batch_mean': 4.732418060302734e-05, 'seconds_per_batch_std': 1.2015429722852173e-06, 'seconds_per_batch_min': 4.6253204345703125e-05, 'seconds_per_batch_max': 5.412101745605469e-05}, 'human_readable': {'batches_per_second': '21.14 K +/- 502.60 [18.48 K, 21.62 K]', 'batch_latency': '47.324 us +/- 1.202 us [46.253 us, 54.121 us]'}}, 'gpu_to_cpu': {'metrics': {'batches_per_second_mean': 66602.83101967598, 'batches_per_second_std': 2356.642719609671, 'batches_per_second_min': 50533.78313253012, 'batches_per_second_max': 69905.06666666667, 'seconds_per_batch_mean': 1.5037059783935547e-05, 'seconds_per_batch_std': 6.441318177259402e-07, 'seconds_per_batch_min': 1.430511474609375e-05, 'seconds_per_batch_max': 1.9788742065429688e-05}, 'human_readable': {'batches_per_second': '66.60 K +/- 2.36 K [50.53 K, 69.91 K]', 'batch_latency': '15.037 us +/- 0.644 us [14.305 us, 19.789 us]'}}, 'total': {'metrics': {'batches_per_second_mean': 315.32228056292024, 'batches_per_second_std': 1.9207919239589497, 'batches_per_second_min': 305.7741488663702, 'batches_per_second_max': 320.0781440781441, 'seconds_per_batch_mean': 0.0031714768409729006, 'seconds_per_batch_std': 1.9425515608681054e-05, 'seconds_per_batch_min': 0.003124237060546875, 'seconds_per_batch_max': 0.003270387649536133}, 'human_readable': {'batches_per_second': '315.32 +/- 1.92 [305.77, 320.08]', 'batch_latency': '3.171 ms +/- 19.426 us [3.124 ms, 3.270 ms]'}}}, 'batch_size_8': {'on_device_inference': {'metrics': {'batches_per_second_mean': 272.37570387880305, 'batches_per_second_std': 2.2435823146744878, 'batches_per_second_min': 257.60373418498955, 'batches_per_second_max': 278.65426521392504, 'seconds_per_batch_mean': 0.0036716485023498536, 'seconds_per_batch_std': 3.0243802171274638e-05, 'seconds_per_batch_min': 0.0035886764526367188, 'seconds_per_batch_max': 0.0038819313049316406}, 'human_readable': {'batches_per_second': '272.38 +/- 2.24 [257.60, 278.65]', 'batch_latency': '3.672 ms +/- 30.244 us [3.589 ms, 3.882 ms]'}}, 'cpu_to_gpu': {'metrics': {'batches_per_second_mean': 3653.2599001171066, 'batches_per_second_std': 25.398058249541723, 'batches_per_second_min': 3524.625210084034, 'batches_per_second_max': 3724.9591474245117, 'seconds_per_batch_mean': 0.0002737414836883545, 'seconds_per_batch_std': 1.9209344377838303e-06, 'seconds_per_batch_min': 0.0002684593200683594, 'seconds_per_batch_max': 0.0002837181091308594}, 'human_readable': {'batches_per_second': '3.65 K +/- 25.40 [3.52 K, 3.72 K]', 'batch_latency': '273.741 us +/- 1.921 us [268.459 us, 283.718 us]'}}, 'gpu_to_cpu': {'metrics': {'batches_per_second_mean': 45164.404228020416, 'batches_per_second_std': 2100.9903917334454, 'batches_per_second_min': 36792.14035087719, 'batches_per_second_max': 47662.545454545456, 'seconds_per_batch_mean': 2.2196054458618163e-05, 'seconds_per_batch_std': 1.178414813981573e-06, 'seconds_per_batch_min': 2.09808349609375e-05, 'seconds_per_batch_max': 2.7179718017578125e-05}, 'human_readable': {'batches_per_second': '45.16 K +/- 2.10 K [36.79 K, 47.66 K]', 'batch_latency': '22.196 us +/- 1.178 us [20.981 us, 27.180 us]'}}, 'total': {'metrics': {'batches_per_second_mean': 252.05720607228778, 'batches_per_second_std': 1.9303535336234505, 'batches_per_second_min': 239.45558346654488, 'batches_per_second_max': 257.5404642023824, 'seconds_per_batch_mean': 0.003967586040496826, 'seconds_per_batch_std': 3.0387728227510695e-05, 'seconds_per_batch_min': 0.003882884979248047, 'seconds_per_batch_max': 0.004176139831542969}, 'human_readable': {'batches_per_second': '252.06 +/- 1.93 [239.46, 257.54]', 'batch_latency': '3.968 ms +/- 30.388 us [3.883 ms, 4.176 ms]'}}}}, 'memory': {'batch_size_1': {'pre_inference_bytes': 26219008, 'max_inference_bytes': 163950592, 'post_inference_bytes': 26219008, 'pre_inference': '25.00 MB', 'max_inference': '156.36 MB', 'post_inference': '25.00 MB'}, 'batch_size_8': {'pre_inference_bytes': 26219008, 'max_inference_bytes': 210211328, 'post_inference_bytes': 26219008, 'pre_inference': '25.00 MB', 'max_inference': '200.47 MB', 'post_inference': '25.00 MB'}}}
trisolaris_results_gpu = {'machine_info': {'system': {'system': 'Linux', 'node': 'trisolaris', 'release': '5.19.0-32-generic'}, 'cpu': {'model': 'AMD Ryzen 7 2700 Eight-Core Processor', 'architecture': 'x86_64', 'cores': {'physical': 8, 'total': 16}, 'frequency': '3.20 GHz'}, 'memory': {'total': '31.28 GB', 'used': '14.74 GB', 'available': '15.58 GB'}, 'gpus': [{'name': 'NVIDIA GeForce RTX 3060', 'memory': '12288.0 MB'}]}, 'device': 'cuda', 'params': 5288548, 'timing': {'batch_size_1': {'on_device_inference': {'metrics': {'batches_per_second_mean': 77.88114219697822, 'batches_per_second_std': 4.076862717297484, 'batches_per_second_min': 54.335289469252395, 'batches_per_second_max': 84.0541883767535, 'seconds_per_batch_mean': 0.012878541946411132, 'seconds_per_batch_std': 0.0007414036688797421, 'seconds_per_batch_min': 0.011897087097167969, 'seconds_per_batch_max': 0.018404245376586914}, 'human_readable': {'batches_per_second': '77.88 +/- 4.08 [54.34, 84.05]', 'batch_latency': '12.879 ms +/- 741.404 us [11.897 ms, 18.404 ms]'}}, 'cpu_to_gpu': {'metrics': {'batches_per_second_mean': 6090.907203673298, 'batches_per_second_std': 260.7112444527272, 'batches_per_second_min': 4860.143684820394, 'batches_per_second_max': 6584.464678178964, 'seconds_per_batch_mean': 0.00016449570655822755, 'seconds_per_batch_std': 7.414120057905994e-06, 'seconds_per_batch_min': 0.0001518726348876953, 'seconds_per_batch_max': 0.00020575523376464844}, 'human_readable': {'batches_per_second': '6.09 K +/- 260.71 [4.86 K, 6.58 K]', 'batch_latency': '164.496 us +/- 7.414 us [151.873 us, 205.755 us]'}}, 'gpu_to_cpu': {'metrics': {'batches_per_second_mean': 20805.329431955524, 'batches_per_second_std': 3355.250827143695, 'batches_per_second_min': 1215.388003477253, 'batches_per_second_max': 27060.025806451613, 'seconds_per_batch_mean': 5.118441581726074e-05, 'seconds_per_batch_std': 3.595836606689201e-05, 'seconds_per_batch_min': 3.695487976074219e-05, 'seconds_per_batch_max': 0.0008227825164794922}, 'human_readable': {'batches_per_second': '20.81 K +/- 3.36 K [1.22 K, 27.06 K]', 'batch_latency': '51.184 us +/- 35.958 us [36.955 us, 822.783 us]'}}, 'total': {'metrics': {'batches_per_second_mean': 76.59737935334535, 'batches_per_second_std': 3.9991060596587755, 'batches_per_second_min': 53.707714962545616, 'batches_per_second_max': 82.6887469442473, 'seconds_per_batch_mean': 0.013094222068786621, 'seconds_per_batch_std': 0.0007524752641809644, 'seconds_per_batch_min': 0.012093544006347656, 'seconds_per_batch_max': 0.018619298934936523}, 'human_readable': {'batches_per_second': '76.60 +/- 4.00 [53.71, 82.69]', 'batch_latency': '13.094 ms +/- 752.475 us [12.094 ms, 18.619 ms]'}}}, 'batch_size_8': {'on_device_inference': {'metrics': {'batches_per_second_mean': 76.40373527492608, 'batches_per_second_std': 3.070932950244047, 'batches_per_second_min': 56.71733986017769, 'batches_per_second_max': 79.52794842624193, 'seconds_per_batch_mean': 0.01311152458190918, 'seconds_per_batch_std': 0.0005792261567009922, 'seconds_per_batch_min': 0.012574195861816406, 'seconds_per_batch_max': 0.01763129234313965}, 'human_readable': {'batches_per_second': '76.40 +/- 3.07 [56.72, 79.53]', 'batch_latency': '13.112 ms +/- 579.226 us [12.574 ms, 17.631 ms]'}}, 'cpu_to_gpu': {'metrics': {'batches_per_second_mean': 1175.7158534452146, 'batches_per_second_std': 16.27855754536896, 'batches_per_second_min': 956.075678139959, 'batches_per_second_max': 1193.9379447765443, 'seconds_per_batch_mean': 0.0008507237434387207, 'seconds_per_batch_std': 1.290031436307658e-05, 'seconds_per_batch_min': 0.0008375644683837891, 'seconds_per_batch_max': 0.0010459423065185547}, 'human_readable': {'batches_per_second': '1.18 K +/- 16.28 [956.08, 1.19 K]', 'batch_latency': '850.724 us +/- 12.900 us [837.564 us, 1.046 ms]'}}, 'gpu_to_cpu': {'metrics': {'batches_per_second_mean': 17033.760376974544, 'batches_per_second_std': 1558.2222420777075, 'batches_per_second_min': 993.9109004739337, 'batches_per_second_max': 19418.074074074073, 'seconds_per_batch_mean': 6.103706359863281e-05, 'seconds_per_batch_std': 4.167337838496204e-05, 'seconds_per_batch_min': 5.14984130859375e-05, 'seconds_per_batch_max': 0.0010061264038085938}, 'human_readable': {'batches_per_second': '17.03 K +/- 1.56 K [993.91, 19.42 K]', 'batch_latency': '61.037 us +/- 41.673 us [51.498 us, 1.006 ms]'}}, 'total': {'metrics': {'batches_per_second_mean': 71.42421146080996, 'batches_per_second_std': 2.737739323897987, 'batches_per_second_min': 53.75796570198149, 'batches_per_second_max': 74.19476039695034, 'seconds_per_batch_mean': 0.014023285388946533, 'seconds_per_batch_std': 0.0005880028482628907, 'seconds_per_batch_min': 0.01347804069519043, 'seconds_per_batch_max': 0.01860189437866211}, 'human_readable': {'batches_per_second': '71.42 +/- 2.74 [53.76, 74.19]', 'batch_latency': '14.023 ms +/- 588.003 us [13.478 ms, 18.602 ms]'}}}}, 'memory': {'batch_size_1': {'pre_inference_bytes': 26219008, 'max_inference_bytes': 163950592, 'post_inference_bytes': 26219008, 'pre_inference': '25.00 MB', 'max_inference': '156.36 MB', 'post_inference': '25.00 MB'}, 'batch_size_8': {'pre_inference_bytes': 26219008, 'max_inference_bytes': 210211328, 'post_inference_bytes': 26219008, 'pre_inference': '25.00 MB', 'max_inference': '200.47 MB', 'post_inference': '25.00 MB'}}}

# %%
trisolaris_gpu = pd.DataFrame(trisolaris_results_gpu)
marvin_gpu = pd.DataFrame(marvin_results_gpu)

# %%
trisolaris_gpu
# Out:
#                                                    machine_info device  \
# system        {'system': 'Linux', 'node': 'trisolaris', 'rel...   cuda
# cpu           {'model': 'AMD Ryzen 7 2700 Eight-Core Process...   cuda
# memory        {'total': '31.28 GB', 'used': '14.74 GB', 'ava...   cuda
# gpus          [{'name': 'NVIDIA GeForce RTX 3060', 'memory':...   cuda
# batch_size_1                                                NaN   cuda
# batch_size_8                                                NaN   cuda
#
#                params                                             timing  \
# system        5288548                                                NaN
# cpu           5288548                                                NaN
# memory        5288548                                                NaN
# gpus          5288548                                                NaN
# batch_size_1  5288548  {'on_device_inference': {'metrics': {'batches_...
# ...

# %%
import matplotlib.pyplot as plt

bars = ('min', 'min', 'mean', 'mean', 'max', 'max')
x_pos = range(len(bars))

plt.bar(0, trisolaris_gpu.timing.batch_size_8["on_device_inference"]["metrics"]["batches_per_second_min"],  color="orange", alpha=0.5, label="RTX 3060 12GB")#, marker=metric_marker[i])
plt.bar(2, trisolaris_gpu.timing.batch_size_8["on_device_inference"]["metrics"]["batches_per_second_mean"],  color="orange", alpha=0.5)#, marker=metric_marker[i])
plt.bar(4, trisolaris_gpu.timing.batch_size_8["on_device_inference"]["metrics"]["batches_per_second_max"], color="orange", alpha=0.5)#, marker=metric_marker[i])

plt.bar(1, marvin_gpu.timing.batch_size_8["on_device_inference"]["metrics"]["batches_per_second_min"], color="blue", alpha=0.5, label="Nvidia 4090 24GB")#, marker=metric_marker[i])
plt.bar(3, marvin_gpu.timing.batch_size_8["on_device_inference"]["metrics"]["batches_per_second_mean"],color="blue", alpha=0.5)#, marker=metric_marker[i])
plt.bar(5, marvin_gpu.timing.batch_size_8["on_device_inference"]["metrics"]["batches_per_second_max"], color="blue", alpha=0.5)#, marker=metric_marker[i])

# Choose the names of the bars

# Create bars

# Create names on the x-axis
plt.xticks(x_pos, bars, color='black')
plt.yticks(color='black')
plt.ylabel("Batches per second")

plt.title("Simple GPU Benchmark Comparison -- Higher is Better \n Batch Size = 8, N Samples = 1000")
plt.legend(loc="lower right")
